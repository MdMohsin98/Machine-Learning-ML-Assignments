# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('Salaries.csv')
df
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_4696\3499069451.py:1: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('Salaries.csv')
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148643  148646   Carolyn A Wilson
# 148644  148648     Joann Anderson
# 148645  148649        Leon Walker
# 148646  148650      Roy I Tillery
# 148647  148654          Joe Lopez
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00
# ...

# %%
grouped = df.groupby('Year')
grouped.sum()
# Out:
#               Id       BasePay   OvertimePay      OtherPay      Benefits  \
# Year
# 2011   653740922  2.299508e+09  1.638191e+08  1.307857e+08  0.000000e+00
# 2012  2005265403  2.405753e+09  1.846650e+08  1.343185e+08  9.720538e+08
# 2013  3449541971  2.576381e+09  1.986214e+08  1.436538e+08  8.961163e+08
# 2014  4939879336  2.537369e+09  2.059186e+08  1.336232e+08  9.449548e+08
#
#           TotalPay  TotalPayBenefits  Notes
# Year
# 2011  2.594113e+09      2.594113e+09    0.0
# 2012  2.724736e+09      3.696790e+09    0.0
# 2013  2.918656e+09      3.814772e+09    0.0
# 2014  2.876911e+09      3.821866e+09    0.0

# %%
# Difference between the salary cost of 2011 and 2014
y1 =  grouped[TotalPay[2014]]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [16], in <module>
#       1 # Difference between the salary cost of 2011 and 2014
# ----> 2 y1 =  grouped[TotalPay[2014]]
#
# NameError: name 'TotalPay' is not defined

# %%
df = pd.DataFrame({'first_name' : ['Jason', 'olly', 'Tina', 'Jake', 'Amy'], 
'last_name' : ['Miller', 'Jacobson', '.', 'Milner','Cooze'],
'age' : [42, 52, 36, 24, 73], 
'preTestScore' : [4, 24, 31, '.', '.'],
'postTestScore' : ['25000', '94000', 57, 62, 70]})

# %%
df.to_csv('project.csv', index=False)

# %%
pd.read_csv('project.csv')
# Out:
#   first_name last_name  age preTestScore  postTestScore
# 0      Jason    Miller   42            4          25000
# 1       olly  Jacobson   52           24          94000
# 2       Tina         .   36           31             57
# 3       Jake    Milner   24            .             62
# 4        Amy     Cooze   73            .             70

# %%
# Without heading
pd.read_csv('project.csv', skiprows=1)
# Out:
#   Jason    Miller  42   4  25000
# 0  olly  Jacobson  52  24  94000
# 1  Tina         .  36  31     57
# 2  Jake    Milner  24   .     62
# 3   Amy     Cooze  73   .     70

# %%
# Making the first and last name as index
df = pd.read_csv('project.csv', index_col=['first_name', 'last_name'])
df
# Out:
#                       age preTestScore  postTestScore
# first_name last_name
# Jason      Miller      42            4          25000
# olly       Jacobson    52           24          94000
# Tina       .           36           31             57
# Jake       Milner      24            .             62
# Amy        Cooze       73            .             70

# %%
def null_valuesofdf(x):
    if x.isnull().any():
        return 'False'
    else:
        return 'True'
print(null_valuesofdf(df))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [36], in <module>
#       4     else:
#       5         return 'True'
# ----> 6 print(null_valuesofdf(df))
#
# Input In [36], in null_valuesofdf(x)
#       1 def null_valuesofdf(x):
# ----> 2     if x.isnull().any():
#       3         return 'False'
#       4     else:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:1535, in NDFrame.__nonzero__(self)
#    1533 @final
#    1534 def __nonzero__(self):
# -> 1535     raise ValueError(
#    1536         f"The truth value of a {type(self).__name__} is ambiguous. "
#    1537         "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1538     )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
# Skipping first three rows
df = pd.read_csv('project.csv', skiprows=3)
df
# Out:
#    Tina       .  36 31  57
# 0  Jake  Milner  24  .  62
# 1   Amy   Cooze  73  .  70
